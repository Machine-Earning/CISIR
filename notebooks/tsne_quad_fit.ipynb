# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.manifold import TSNE

# Generate dummy data
n_samples = 300
n_features = 50
centers = 5
random_state = 42

X, y = make_blobs(n_samples=n_samples, n_features=n_features, centers=centers, random_state=random_state)

# t-SNE with different levels of early exaggeration
exaggeration_levels = [1, 12, 24]  # low, medium, high
tsne_results = []

for exaggeration in exaggeration_levels:
    tsne = TSNE(n_components=2, early_exaggeration=exaggeration, random_state=random_state)
    X_tsne = tsne.fit_transform(X)
    tsne_results.append((X_tsne, exaggeration))

# Plot the results
plt.figure(figsize=(18, 5))
for i, (X_tsne, exaggeration) in enumerate(tsne_results):
    plt.subplot(1, 3, i + 1)
    scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis', s=15)
    plt.title(f't-SNE with Early Exaggeration = {exaggeration}')
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.colorbar(scatter, ax=plt.gca())

plt.suptitle('t-SNE Visualization with Different Levels of Early Exaggeration')
plt.show()

# %%
from modules.training.smooth_early_stopping import find_optimal_epoch_by_smoothing, find_optimal_epoch_by_quadratic_fit

# %%
# Example usage with dummy data
dummy_metric_history = [5, 3, 1, 2, 4, 6]
optimal_epoch_with_optional_plot = find_optimal_epoch_by_quadratic_fit(dummy_metric_history, plot=True)
print(f'Optimal epoch: {optimal_epoch_with_optional_plot}')
# Out:
# Optimal epoch: 3.3

# %%
# Example usage with dummy data
dummy_metric_history = [5, 3, 6, 0, 4, 6, 1, 1, 7]
optimal_epoch_with_optional_plot = find_optimal_epoch_by_quadratic_fit(dummy_metric_history, plot=True)
print(f'Optimal epoch: {optimal_epoch_with_optional_plot}')
# Out:
# Optimal epoch: 5.122222222222223

# %%
# Example usage with dummy data
dummy_metric_history = [100, 50, 10, 5, -6, 6, 7, 6, 3, 1, 1, 1, 2, 7]
optimal_epoch_with_optional_plot = find_optimal_epoch_by_quadratic_fit(dummy_metric_history, plot=True)
print(f'Optimal epoch: {optimal_epoch_with_optional_plot}')
# Out:
# Optimal epoch: 9.29519408502773

# %%
# Example usage with dummy data
dummy_metric_history = [100, 50, 10, 5, -6, 6, 7, 6, 3, 1, 1, 1, 2, 7]
optimal_epoch_with_optional_plot = find_optimal_epoch_by_smoothing(
    dummy_metric_history,
    smoothing_method='moving_average',
    smoothing_parameters={'window_size': 5},
    plot=True)
print(f'Optimal epoch: {optimal_epoch_with_optional_plot}')
# Out:
# Optimal epoch: 11

# %%
# Example usage with dummy data
dummy_metric_history = [100, 50, 10, 5, -6, 6, 7, 6, 3, 1, 1, 1, 2, 7]
optimal_epoch_with_optional_plot = find_optimal_epoch_by_smoothing(
    dummy_metric_history,
    smoothing_method='exponential_moving_average',
    smoothing_parameters={'alpha': 0.5},
    plot=True)
print(f'Optimal epoch: {optimal_epoch_with_optional_plot}')
# Out:
# Optimal epoch: 11

# %%
# Example usage with dummy data
dummy_metric_history = [100, 50, 10, 5, -6, 6, 7, 6, 3, 1, 1, 1, 2, 7]
optimal_epoch_with_optional_plot = find_optimal_epoch_by_smoothing(
    dummy_metric_history,
    smoothing_method='gaussian',
    smoothing_parameters={'window_size': 5, 'std': 1},
    plot=True)
print(f'Optimal epoch: {optimal_epoch_with_optional_plot}')
# Out:
# Optimal epoch: 11

# %%
"""
Observation, window size should be large enough to overcome a severe dip in epochs
"""
