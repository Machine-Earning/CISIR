# %%
import numpy as np
import pandas as pd
from numpy import ndarray
from scipy.stats import gaussian_kde
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.utils import shuffle
# types for type hinting
from typing import Tuple
from dataload import DenseReweights as dr

# %%
from dataload import seploader as sepl

loader = sepl.SEPLoader()

# %%
# loader.load('../cme_and_electron/cme_josias_10MeV.csv', outupt_dir='../cme_and_electron/data')

# %%
train_x, train_y, val_x, val_y, test_x, test_y = loader.load_from_dir('../cme_and_electron/data')

# %%
# Read the CSV file
file_path = '../cme_and_electron/cme_josias_10MeV.csv'
df = pd.read_csv(file_path)

# %%
def split_data(df):
    """
    Splits the data into training, validation, and test sets according to the specified rules.
    
    :param:
    - df: DataFrame containing the data. Assumes 'log_peak_intensity' is the target column.
    
    :return:
    - train_x, train_y, val_x, val_y, test_x, test_y: Numpy arrays containing the split data
    """
    # Sort the DataFrame by 'log_peak_intensity' in descending order
    df_sorted = df.sort_values(by='log_peak_intensity', ascending=False).reset_index(drop=True)
    
    # Initialize empty lists to store indices for training, validation, and test sets
    train_indices = []
    val_indices = []
    test_indices = []
    
    # Group every 3 rows for test set selection
    for i in range(0, len(df_sorted), 3):
        group = list(range(i, min(i + 3, len(df_sorted))))
        test_idx = np.random.choice(group, 1)[0]
        train_indices.extend([idx for idx in group if idx != test_idx])
        test_indices.append(test_idx)
    
    # Group every 4 rows for validation set selection from the training set
    for i in range(0, len(train_indices), 4):
        group = train_indices[i: i + 4]
        if len(group) == 0:
            continue
        val_idx = np.random.choice(group, 1)[0]
        val_indices.append(val_idx)
        train_indices = [idx for idx in train_indices if idx != val_idx]
    
    # Extract the feature and target sets based on selected indices
    features = df_sorted.drop(columns=['log_peak_intensity']).to_numpy()
    target = df_sorted['log_peak_intensity'].to_numpy()
    
    train_x = features[train_indices]
    train_y = target[train_indices]
    val_x = features[val_indices]
    val_y = target[val_indices]
    test_x = features[test_indices]
    test_y = target[test_indices]
    
    return train_x, train_y, val_x, val_y, test_x, test_y

# Test the function
train_x, train_y, val_x, val_y, test_x, test_y = split_data(df)

# Show the shape of the resulting arrays to ensure correctness
(train_x.shape, train_y.shape), (val_x.shape, val_y.shape), (test_x.shape, test_y.shape)
# Out:
# (((1225, 19), (1225,)), ((307, 19), (307,)), ((766, 19), (766,)))

# %%
def plot_sorted_distributions(y_train, y_val, y_test, title='Sorted Distributions'):
    """
    Plots the sorted target variable distributions for the training, validation, and test sets.
    
    :param:
    - y_train: Numpy array containing the training set target variable
    - y_val: Numpy array containing the validation set target variable
    - y_test: Numpy array containing the test set target variable
    - title: Title for the plot
    """
    plt.figure(figsize=(12, 6))
    
    # Sort and plot the target variable for each set
    plt.plot(np.sort(y_train), label='Train', marker='o')
    plt.plot(np.sort(y_val), label='Validation', marker='x')
    plt.plot(np.sort(y_test), label='Test', marker='s')
    
    plt.xlabel('Index')
    plt.ylabel('log_peak_intensity')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_sorted_distributions(train_y, val_y, test_y, title='Sorted Distributions of log_peak_intensity')

# %%
concatenated_x, concatenated_y = concatenate_datasets(train_x, train_y, val_x, val_y, test_x, test_y)

# %%
# get validation sample weights based on dense weights
sample_weights = dr.DenseReweights(concatenated_x, concatenated_y, alpha=.9, debug=True).reweights
# Out:
# X_train:  [[0.10263593 0.12737226 0.14174757 0.11748927 0.         0.11829945
#   0.38961039 0.4        0.25555556 0.27638191 0.27586207 0.47752809
#   0.25197016 0.22222222 0.         0.836019   0.40458495 0.
#   0.        ]
#  [0.05305486 0.07591241 0.13268608 0.1123927  0.         0.06395564
#   0.15584416 0.34444444 0.30555556 0.12562814 0.20689655 0.41573034
#   0.25932542 0.31666667 0.         0.90422584 0.32124345 0.
#   0.        ]
#  [0.20593914 0.25218978 0.27346278 0.22103004 0.         0.24251386
#   0.24675325 0.18055556 0.38611111 0.16080402 0.34482759 0.23595506
#   0.25764422 0.34166667 0.         0.93730677 0.82838906 0.
#   0.        ]
#  [0.0621716  0.12408759 0.16213592 0.11856223 0.         0.11275416
#   0.41558442 0.32222222 0.31944444 0.3919598  0.17241379 0.33707865
#   0.26037617 0.36388889 0.         0.90245624 0.40027608 0.
#   0.        ]
#  [0.16885977 0.22153285 0.21294498 0.17730687 0.         0.21146026
#   0.5974026  0.24444444 0.31666667 0.53266332 0.09195402 0.33146067
#   0.25081433 0.34444444 0.25       0.94137248 0.55526034 0.
#   0.        ]
#  [0.1550328  0.17627737 0.22815534 0.17247854 0.         0.22365989
#   0.36363636 0.25       0.62222222 0.74371859 0.17241379 0.60674157
#   0.26310812 0.17777778 0.25       0.94466353 0.45990486 0.
#   0.        ]
#  [0.06427929 0.17956204 0.13559871 0.09951717 0.         0.22624769
#   0.67532468 0.14444444 0.01944444 0.68844221 0.20689655 0.98876404
#   0.25680361 0.         0.5        0.86298536 0.46310235 0.
#   0.        ]
#  [0.06639535 0.13649635 0.10194175 0.09468884 0.         0.12532348
#   0.2987013  0.74166667 0.98888889 0.17085427 0.22988506 0.38764045
#   0.25375644 0.96944444 0.         0.62967066 0.41620003 0.
#   0.        ]
#  [0.06427929 0.10839416 0.15113269 0.11534335 0.         0.19445471
#   0.2987013  0.28888889 0.3        0.35175879 0.22988506 0.37640449
#   0.25932542 0.3        0.         0.95241922 0.37789728 0.
#   0.        ]
#  [0.56629963 0.52810219 0.72944984 0.56035408 0.5        0.5219963
#   0.32467532 0.375      0.21666667 0.58291457 0.51724138 0.56179775
#   0.33592519 1.         0.25       0.90241993 0.9936771  0.90602558
#   1.        ]
#  [0.07091879 0.09124088 0.12491909 0.21351931 0.         0.16081331
#   0.7012987  0.48333333 0.48611111 0.38693467 0.25287356 0.98876404
#   0.27729326 0.525      0.25       0.8584032  0.35015448 0.
#   0.        ]
#  [0.10711297 0.19160584 0.12135922 0.06410944 0.5        0.55637708
#   0.67532468 0.62777778 0.59722222 0.51758794 0.14942529 0.29775281
#   0.24198802 0.60555556 0.25       0.73533227 0.47437449 0.
#   0.        ]]
# y_train:  [-1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791
#  -1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791]
# reweights:  [0.75306975 0.75306975 0.75306975 0.75306975 0.75306975 0.75306975
#  0.75306975 0.75306975 0.75306975 0.75306975 0.75306975 0.75306975]
# Density at min_y background (-1.6094379124341005): 1.9072847890306113
# Density at max_y Sep (8.732078739083455): 0.0017006617778946693
# Density at max_y lower Sep (7.732078739083455): 0.0017006617778946693
# Density at y=1.4 elevated: 0.0006128379197299409
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 # get validation sample weights based on dense weights
# ----> 2 sample_weights = dr.DenseReweights(concatenated_x, concatenated_y, alpha=.9, debug=True).reweights
#
# File ~\OneDrive\Desktop\school\Fall 2023\keras-functional-api\dataload\DenseReweights.py:302, in DenseReweights.__init__(self, X, y, alpha, debug)
#     300 print('y_train: ', self.y_train[:12])
#     301 print('reweights: ', self.reweights[:12])
# --> 302 self.plot_density_kde_reweights()
#
# File ~\OneDrive\Desktop\school\Fall 2023\keras-functional-api\dataload\DenseReweights.py:430, in DenseReweights.plot_density_kde_reweights(self)
#     427 print(f"Density at y=1.4 elevated: {density_values[2]}")
#     429 # get the avg density for background and seps
# --> 430 bg_density, seps_density = self.calculate_event_density(y_values)
#     431 print(f'Avg density for backrgound: {bg_density}')
#     432 print(f'Avg density for seps: {seps_density}')
#
# File ~\OneDrive\Desktop\school\Fall 2023\keras-functional-api\dataload\DenseReweights.py:474, in DenseReweights.calculate_event_density(self, y_values)
#     472 # Calculate the density at multiple points and take the mean to get an average density
#     473 evaluation_points = np.linspace(min(y_values), max(y_values), 1000)
# --> 474 avg_background_density = np.mean(background_kde.evaluate(evaluation_points))
#     475 avg_sep_density = np.mean(sep_kde.evaluate(evaluation_points))
#     477 return avg_background_density, avg_sep_density
#
# AttributeError: 'numpy.ndarray' object has no attribute 'evaluate'

# %%
# get validation sample weights based on dense weights
sample_weights = dr.DenseReweights(train_x, train_y, alpha=.9, debug=True).reweights
val_sample_weights = dr.DenseReweights(val_x, val_y, alpha=.9, debug=True).reweights
# Out:
# X_train:  [[0.10263593 0.12737226 0.14174757 0.11748927 0.         0.11829945
#   0.38961039 0.4        0.25555556 0.27638191 0.27586207 0.47752809
#   0.25197016 0.22222222 0.         0.836019   0.40458495 0.
#   0.        ]
#  [0.05305486 0.07591241 0.13268608 0.1123927  0.         0.06395564
#   0.15584416 0.34444444 0.30555556 0.12562814 0.20689655 0.41573034
#   0.25932542 0.31666667 0.         0.90422584 0.32124345 0.
#   0.        ]
#  [0.20593914 0.25218978 0.27346278 0.22103004 0.         0.24251386
#   0.24675325 0.18055556 0.38611111 0.16080402 0.34482759 0.23595506
#   0.25764422 0.34166667 0.         0.93730677 0.82838906 0.
#   0.        ]
#  [0.0621716  0.12408759 0.16213592 0.11856223 0.         0.11275416
#   0.41558442 0.32222222 0.31944444 0.3919598  0.17241379 0.33707865
#   0.26037617 0.36388889 0.         0.90245624 0.40027608 0.
#   0.        ]
#  [0.16885977 0.22153285 0.21294498 0.17730687 0.         0.21146026
#   0.5974026  0.24444444 0.31666667 0.53266332 0.09195402 0.33146067
#   0.25081433 0.34444444 0.25       0.94137248 0.55526034 0.
#   0.        ]
#  [0.1550328  0.17627737 0.22815534 0.17247854 0.         0.22365989
#   0.36363636 0.25       0.62222222 0.74371859 0.17241379 0.60674157
#   0.26310812 0.17777778 0.25       0.94466353 0.45990486 0.
#   0.        ]
#  [0.06427929 0.17956204 0.13559871 0.09951717 0.         0.22624769
#   0.67532468 0.14444444 0.01944444 0.68844221 0.20689655 0.98876404
#   0.25680361 0.         0.5        0.86298536 0.46310235 0.
#   0.        ]
#  [0.23885999 0.46861314 0.28802589 0.24114807 0.5        0.46173752
#   0.41558442 0.42777778 0.06944444 0.51758794 0.20689655 0.65168539
#   0.25070926 0.08888889 0.5        0.85115083 0.98877758 0.
#   0.        ]
#  [0.19448932 0.27007299 0.2197411  0.11883047 0.         0.59334566
#   0.44155844 0.94444444 0.79444444 0.48241206 0.28735632 0.57865169
#   0.23042976 0.83888889 0.25       0.88698408 0.88100072 0.
#   0.        ]
#  [0.04818258 0.07992701 0.11747573 0.23256438 0.         0.11977819
#   0.19480519 0.74166667 0.76666667 0.         0.22988506 0.48314607
#   0.28464852 0.74166667 0.         0.63342712 0.32925314 0.
#   0.        ]
#  [0.06269772 0.08357664 0.10226537 0.097103   0.         0.10536044
#   0.46753247 0.93055556 0.65277778 0.18090452 0.16091954 0.38202247
#   0.25480719 0.64722222 0.25       0.82885403 0.33621509 0.
#   0.        ]
#  [0.11330467 0.21021898 0.18770227 0.21083691 0.         0.3271719
#   0.46753247 0.68055556 0.75277778 0.66331658 0.35632184 0.52808989
#   0.27361564 0.75555556 0.25       0.47413818 0.49065475 0.
#   0.        ]]
# y_train:  [-1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791
#  -1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791 -1.60943791]
# reweights:  [0.75656447 0.75656447 0.75656447 0.75656447 0.75656447 0.75656447
#  0.75656447 0.75656447 0.75656447 0.75656447 0.75656447 0.75656447]
# Density at min_y background (-1.6094379124341005): 1.2775113937242946
# Density at max_y Sep (7.416318345093869): 0.004315916870999748
# Density at max_y lower Sep (6.416318345093869): 0.004315916870999748
# Density at y=1.4 elevated: 2.636823585666356e-05

# %%
def shuffle_sets(train_x, train_y, val_x, val_y, test_x, test_y):
    """
    Shuffle the data within each of the training, validation, and test sets.
    
    :param:
    - train_x, train_y: Numpy arrays containing the training features and labels
    - val_x, val_y: Numpy arrays containing the validation features and labels
    - test_x, test_y: Numpy arrays containing the test features and labels
    
    :return:
    - Shuffled versions of train_x, train_y, val_x, val_y, test_x, test_y
    """
    train_x, train_y = shuffle(train_x, train_y)
    val_x, val_y = shuffle(val_x, val_y)
    test_x, test_y = shuffle(test_x, test_y)
    
    return train_x, train_y, val_x, val_y, test_x, test_y

# Shuffle the datasets
shuffled_train_x, shuffled_train_y, shuffled_val_x, shuffled_val_y, shuffled_test_x, shuffled_test_y = shuffle_sets(train_x, train_y, val_x, val_y, test_x, test_y)

# %%
from models import modeling
from sklearn.manifold import TSNE

# %%
mb = modeling.ModelBuilder()

# create my feature extractor
feature_extractor = mb.create_model_pds(input_dim=19, feat_dim=9, hiddens=[18])

# %%
# print model summary
feature_extractor.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 19)]              0
#
#  dense (Dense)               (None, 18)                360
#
#  leaky_re_lu (LeakyReLU)     (None, 18)                0
#
#  dense_1 (Dense)             (None, 9)                 171
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 9)                 0
#
#  normalize_layer (NormalizeL  (None, 9)                0
#  ayer)
#
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot model
mb.plot_model(feature_extractor)

# %%
def plot_tsne(model, X, y):
    """
    Applies t-SNE to the features extracted by the given model and plots them in 2D.
    The color of the points is determined by their label values.
    
    Parameters:
    - model: Trained feature extractor model
    - X: Input data
    - y: Target labels
    
    Returns:
    - A 2D t-SNE plot
    """
    # Extract features using the trained model
    features = model.predict(X)
    
    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    tsne_result = tsne.fit_transform(features)
    
    # Create a scatter plot
    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=y, cmap='viridis', alpha=0.6)

    # Add a color bar
    cbar = plt.colorbar(scatter)
    cbar.set_label('Label Value')

    plt.title('2D t-SNE Visualization')
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')

    plt.show()

# %%
plot_tsne(feature_extractor, shuffled_train_x, shuffled_train_y)

# %%
plot_tsne(feature_extractor, shuffled_test_x, shuffled_test_y)

# %%
import  random
def find_optimized_random_batch_size(y, num_to_catch=3, threshold=np.log(10), num_trials=1000, early_exit_ratio=0.95):
    """
    Optimized function to find the minimum batch size such that, when sampled at random,
    each batch is likely to contain at least 2 rows with target values greater than a given threshold.
    
    Parameters:
    - y: Numpy array containing the target values
    - threshold: The target threshold, default is ln(10)
    - num_trials: Number of trials to perform for each batch size
    - early_exit_ratio: The success ratio to achieve before stopping the trials for a given batch size
    
    Returns:
    - Minimum batch size that fulfills the condition
    """
    # Count the number of elements greater than the threshold
    count_above_threshold = np.sum(y > threshold)
    
    # If there are fewer than 2 elements above the threshold, return a message
    if count_above_threshold < num_to_catch:
        raise ValueError("There are not enough samples with target values greater than the threshold.")
    
    # Loop through possible batch sizes, starting from 2
    for batch_size in range(num_to_catch, len(y) + 1):
        success_count = 0
        
        for trial in range(num_trials):
            # Sample a random batch
            random_batch = random.sample(list(y), batch_size)
            
            # Check if the batch contains at least 2 elements greater than the threshold
            if np.sum(np.array(random_batch) > threshold) >= num_to_catch:
                success_count += 1
            
            # Early exit if success ratio is achieved
            if trial >= 500 and success_count / (trial + 1) >= early_exit_ratio:
                return batch_size

# Find the minimum batch size for the training set that satisfies the condition, using the optimized function
# min_optimized_random_batch_size = find_optimized_random_batch_size(train_y, num_to_catch=3, num_trials=10000, early_exit_ratio=0.99)
# 
# min_optimized_random_batch_size

# %%
mb.train_pds(feature_extractor, shuffled_train_x, shuffled_train_y, shuffled_val_x, shuffled_val_y, epochs=200, batch_size=8)
# Out:
# Run the command line:
#  tensorboard --logdir logs/fit
# Epoch 1/200
# 158/158 [==============================] - 9s 44ms/step - loss: 5.2884 - val_loss: 16.8052
# Epoch 2/200
# 158/158 [==============================] - 6s 40ms/step - loss: 5.1317 - val_loss: 16.2020
# Epoch 3/200
# 158/158 [==============================] - 6s 41ms/step - loss: 4.8469 - val_loss: 15.7904
# Epoch 4/200
# 158/158 [==============================] - 7s 42ms/step - loss: 4.7112 - val_loss: 15.5498
# Epoch 5/200
# 158/158 [==============================] - 6s 41ms/step - loss: 4.5831 - val_loss: 15.5319
# Epoch 6/200
# 158/158 [==============================] - 7s 42ms/step - loss: 4.3751 - val_loss: 15.5773
# Epoch 7/200
# 158/158 [==============================] - 7s 45ms/step - loss: 4.4951 - val_loss: 15.3167
# Epoch 8/200
# 158/158 [==============================] - 6s 40ms/step - loss: 4.4511 - val_loss: 15.3579
# Epoch 9/200
# 158/158 [==============================] - 7s 42ms/step - loss: 4.4456 - val_loss: 15.2816
# Epoch 10/200
# 158/158 [==============================] - 6s 40ms/step - loss: 4.4395 - val_loss: 15.2750
# Epoch 11/200
# 158/158 [==============================] - 7s 43ms/step - loss: 4.3294 - val_loss: 15.2889
# Epoch 12/200
# 158/158 [==============================] - 7s 44ms/step - loss: 4.4035 - val_loss: 15.2814
# Epoch 13/200
# 158/158 [==============================] - 7s 47ms/step - loss: 4.3474 - val_loss: 15.4390
# Epoch 14/200
# 158/158 [==============================] - 7s 47ms/step - loss: 4.3901 - val_loss: 15.3808
# Epoch 15/200
# 158/158 [==============================] - 7s 44ms/step - loss: 4.4544 - val_loss: 15.2444
# Epoch 16/200
# 158/158 [==============================] - 7s 45ms/step - loss: 4.2296 - val_loss: 15.3927
# Epoch 17/200
# 158/158 [==============================] - 7s 43ms/step - loss: 4.
69
# 198/198 [==============================] - 9s 47ms/step - loss: 6.3960
# Epoch 62/69
# 198/198 [==============================] - 10s 48ms/step - loss: 6.2148
# Epoch 63/69
# 198/198 [==============================] - 10s 49ms/step - loss: 6.2694
# Epoch 64/69
# 198/198 [==============================] - 9s 47ms/step - loss: 6.3958
# Epoch 65/69
# 198/198 [==============================] - 9s 46ms/step - loss: 6.0078
# Epoch 66/69
# 198/198 [==============================] - 9s 46ms/step - loss: 6.3873
# Epoch 67/69
# 198/198 [==============================] - 9s 46ms/step - loss: 6.3845
# Epoch 68/69
# 198/198 [==============================] - 9s 46ms/step - loss: 6.3856
# Epoch 69/69
# 198/198 [==============================] - 9s 47ms/step - loss: 6.5213

# %%
plot_tsne(feature_extractor, shuffled_train_x, shuffled_train_y)

# %%
plot_tsne(feature_extractor, shuffled_test_x, shuffled_test_y)

# %% [markdown]
# # test

# %%
res = next(mb.custom_data_generator(shuffled_train_x, shuffled_train_y, 8)) # works but always at the end
print(res)
# Out:
# (array([[0.24173065, 0.29508197, 0.24789644, 0.2068133 , 0.        ,
#         0.196     , 0.6       , 0.73888889, 0.73333333, 0.57286432,
#         0.3908046 , 0.37078652, 0.25081433, 0.74166667, 0.        ,
#         0.99709256, 0.84019664, 0.        , 0.        ],
#        [0.04381429, 0.05163934, 0.12330097, 0.10139485, 0.        ,
#         0.1664    , 0.3625    , 0.81666667, 0.675     , 0.09045226,
#         0.22988506, 0.35393258, 0.25880004, 0.64444444, 0.33333333,
#         0.98229448, 0.21194244, 0.        , 0.        ],
#        [0.66914914, 0.89754098, 0.66472492, 0.53299356, 0.        ,
#         0.        , 0.3125    , 0.61944444, 0.79444444, 0.48241206,
#         0.63218391, 0.63483146, 0.30019964, 1.        , 0.        ,
#         0.99944864, 0.99938608, 0.88181017, 1.        ],
#        [0.26104483, 0.50327869, 0.19352751, 0.11883047, 0.        ,
#         0.4228    , 0.45      , 0.375     , 0.25      , 0.40703518,
#         0.06896552, 0.51123596, 0.20994011, 0.25      , 0.        ,
#         0.75249562, 0.98165045, 0.        , 0.        ],
#        [0.55925869, 0.45696721, 0.4592233 , 0.40396996, 0.        ,
#         0.34      , 0.15      , 0.67222222, 0.775     , 0.30653266,
#         0.17241379, 0.42696629, 0.20962488, 1.        , 0.        ,
#         0.99422612, 0.97339336, 0.68308849, 1.        ],
#        [0.08024523, 0.22172131, 0.10226537, 0.08610515, 0.        ,
#         0.252     , 0.9625    , 0.00833333, 0.        , 0.75879397,
#         0.35632184, 0.76966292, 0.25270568, 0.84444444, 0.        ,
#         0.9729648 , 0.41040102, 0.        , 0.        ],
#        [0.22546557, 0.28278689, 0.1789644 , 0.16604077, 0.        ,
#         0.        , 0.4       , 0.15277778, 0.22222222, 0.24623116,
#         0.24137931, 0.57865169, 0.23295156, 0.25      , 0.        ,
#         0.87419544, 0.79920783, 0.54281483, 0.        ],
#        [0.06666867, 0.18852459, 0.08381877, 0.06786481, 0.        ,
#         0.        , 0.375     , 0.56111111, 0.48055556, 0.63316583,
#         0.28735632, 0.36516854, 0.25176001, 0.47777778, 0.        ,
#         0.99357492, 0.38629943, 0.        , 0.        ]]), array([0.30258509, 0.30258509, 6.13630055, 0.30258509, 3.47670675,
#        0.30258509, 0.30258509, 0.30258509]))

# %%
mb.train_pds_injection(feature_extractor, shuffled_train_x, shuffled_train_y, shuffled_val_x, shuffled_val_y, epochs=200, batch_size=8)
# Out:
# Run the command line:
#  tensorboard --logdir logs/fit
# Epoch 1/200
#  75/158 [=============>................] - ETA: 3s - loss: 216.5374
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 mb.train_pds_injection(feature_extractor, shuffled_train_x, shuffled_train_y, shuffled_val_x, shuffled_val_y, epochs=200, batch_size=8)
#
# File ~\OneDrive\Desktop\school\Fall 2023\keras-functional-api\models\modeling.py:474, in ModelBuilder.train_pds_injection(self, model, X_train, y_train, X_val, y_val, sample_joint_weights, learning_rate, epochs, batch_size, patience)
#     471 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=self.repr_loss)
#     473 # First train the model with a validation set to determine the best epoch
# --> 474 history = model.fit(train_gen,
#     475                     steps_per_epoch=train_steps,
#     476                     validation_data=val_gen,
#     477                     validation_steps=val_steps,
#     478                     epochs=epochs,
#     479                     batch_size=batch_size,
#     480                     callbacks=callback_list)
#     482 # Get the best epoch from early stopping
#     483 best_epoch = np.argmin(history.history['val_loss']) + 1
#
# File ~\anaconda3\envs\aip\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\aip\lib\site-packages\keras\engine\training.py:1376, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1374 callbacks.on_epoch_begin(epoch)
#    1375 with data_handler.catch_stop_iteration():
# -> 1376   for step in data_handler.steps():
#    1377     with tf.profiler.experimental.Trace(
#    1378         'train',
#    1379         epoch_num=epoch,
#    1380         step_num=step,
#    1381         batch_size=batch_size,
#    1382         _r=1):
#    1383       callbacks.on_train_batch_begin(step)
#
# File ~\anaconda3\envs\aip\lib\site-packages\keras\engine\data_adapter.py:1246, in DataHandler.steps(self)
#    1244 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1245   break
# -> 1246 original_spe = self._steps_per_execution.numpy().item()
#    1247 can_run_full_execution = (
#    1248     original_spe == 1 or
#    1249     self._inferred_steps is None or
#    1250     self._inferred_steps - self._current_step >=
#    1251     original_spe)
#    1253 if can_run_full_execution:
#
# File ~\anaconda3\envs\aip\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:674, in BaseResourceVariable.numpy(self)
#     672 def numpy(self):
#     673   if context.executing_eagerly():
# --> 674     return self.read_value().numpy()
#     675   raise NotImplementedError(
#     676       "numpy() is only available when eager execution is enabled.")
#
# File ~\anaconda3\envs\aip\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:749, in BaseResourceVariable.read_value(self)
#     740 """Constructs an op which reads the value of this variable.
#     741
#     742 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     746  the read operation.
#     747 """
#     748 with ops.name_scope("Read"):
# --> 749   value = self._read_variable_op()
#     750 # Return an identity so it can get placed on whatever device the context
#     751 # specifies instead of the device where the variable is.
#     752 return array_ops.identity(value)
#
# File ~\anaconda3\envs\aip\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:728, in BaseResourceVariable._read_variable_op(self)
#     726       result = read_and_set_handle()
#     727 else:
# --> 728   result = read_and_set_handle()
#     730 if not context.executing_eagerly():
#     731   # Note that if a control flow context is active the input of the read op
#     732   # might not actually be the handle. This line bypasses it.
#     733   tape.record_operation(
#     734       "ReadVariableOp", [result], [self.handle],
#     735       backward_function=lambda x: [x],
#     736       forward_function=lambda x: [x])
#
# File ~\anaconda3\envs\aip\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:718, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle()
#     717 def read_and_set_handle():
# --> 718   result = gen_resource_variable_ops.read_variable_op(
#     719       self.handle, self._dtype)
#     720   _maybe_set_handle_data(self._dtype, self.handle, result)
#     721   return result
#
# File ~\anaconda3\envs\aip\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:478, in read_variable_op(resource, dtype, name)
#     476 if tld.is_eager:
#     477   try:
# --> 478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     479       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     480     return _result
#     481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
    shuffled_val_y, 
    sample_weights=sample_weights.reweights,  
    sample_val_weights=val_sample_weights.reweights,
    learning_rate=1e-4,
    epochs=1, batch_size=16)
# Out:
# Run the command line:
#  tensorboard --logdir logs/fit
# 79/79 [==============================] - 2s 12ms/step - loss: 2.2542 - regression_head_loss: 2.2542 - val_loss: 2.2169 - val_regression_head_loss: 2.2169
# 99/99 [==============================] - 1s 6ms/step - loss: 2.0705 - regression_head_loss: 2.0705

# %%
def plot_tsne_pds_extended_model(model, X, y, prefix='', save_tag=None):
    """
    Applies t-SNE to the features extracted by the given extended model and saves the plot in 2D with a timestamp.
    The color of the points is determined by their label values.

    Parameters:
    - model: Trained extended feature extractor model
    - X: Input data (NumPy array or compatible)
    - y: Target labels (NumPy array or compatible)
    - prefix: Prefix for the file name

    Returns:
    - Saves a 2D t-SNE plot to a file with a timestamp
    """
    # saving the threshold
    threshold = np.log(10)
    
    # Extract features using the trained extended model
    features, _ = model.predict(X)

    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    tsne_result = tsne.fit_transform(features)

    # Identify above and below threshold indices
    above_threshold_indices = np.where(y > threshold)[0]
    below_threshold_indices = np.where(y <= threshold)[0]

    # Create scatter plot for below-threshold points
    plt.figure(figsize=(12, 8))
    plt.scatter(tsne_result[below_threshold_indices, 0], tsne_result[below_threshold_indices, 1],
                c=y[below_threshold_indices], cmap='viridis', alpha=0.6, label='Below Threshold')

    # Overlay scatter plot for above-threshold points
    scatter = plt.scatter(tsne_result[above_threshold_indices, 0], tsne_result[above_threshold_indices, 1],
                          c=y[above_threshold_indices], cmap='viridis', alpha=1.0, edgecolors='r',
                          label='Above Threshold')

    # Add a color bar
    cbar = plt.colorbar(scatter)
    cbar.set_label('Label Value')

    # Add legend to differentiate above-threshold points
    plt.legend()

    plt.title('2D t-SNE Visualization')
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')

    # Save the plot
    file_path = f"{prefix}_tsne_plot_{str(save_tag)}.png"
    plt.savefig(file_path)
    plt.close()

# %%
plot_tsne_pds_extended_model(extended_model, shuffled_train_x, shuffled_train_y)

# %%
from evaluate import evaluation as eval

ev = eval.Evaluator()

# %%
ev.evaluate(extended_model, shuffled_train_x, shuffled_train_y, threshold=10)
# Out:
# Mean Absolute Error: 0.37659206986427307
# Sample with y = 4.54312455501621 belongs to bin 9 and has an error of 4.666612750256707
# Sample with y = 5.772126246634751 belongs to bin 11 and has an error of 5.863367129508286
# Sample with y = 6.691624580035713 belongs to bin 13 and has an error of 6.713342255065944
# Sample with y = 7.428036061518883 belongs to bin 15 and has an error of 7.41456997155497
# Sample with y = 7.416318345093869 belongs to bin 15 and has an error of 7.522452655458592
# 0.37659207

# %%
ev.evaluate(extended_model, shuffled_test_x, shuffled_test_y, threshold=10)
# Out:
# Mean Absolute Error: 0.3791730999946594
# Sample with y = 0.3025850929940457 belongs to bin 1 and has an error of 0.5205033399785275
# Sample with y = 4.342011606135645 belongs to bin 9 and has an error of 4.395205436089316
# Sample with y = 4.755054635525384 belongs to bin 9 and has an error of 4.851883953035512
# Sample with y = 6.136300551153431 belongs to bin 12 and has an error of 6.23472216949583
# Sample with y = 8.732078739083455 belongs to bin 17 and has an error of 8.854018733478235
# 0.3791731
